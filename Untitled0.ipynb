# %%
# This mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive')

# TODO: Enter the foldername in your Drive where you have saved the unzipped
# assignment folder, e.g. 'cs231n/assignments/assignment2/'
FOLDERNAME = 'ai/cs224n/projects/cs224n_final_project-main'
assert FOLDERNAME is not None, "[!] Enter the foldername."

# Now that we've mounted your Drive, this ensures that
# the Python interpreter of the Colab VM can load
# python files from within it.
import sys
sys.path.append('/content/drive/MyDrive/ai/cs224n')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/ai/cs224n/
# Out:
# /content/drive/.shortcut-targets-by-id/1Kd4FET4j1OALvmuDM1cj16zdimIdzQbu/cs224n

# %%
# %ls
# Out:
#  base_bert.py    env-cpu.yml               optimizer_test.npy   sanity_check.data
#  bert_pal.py     env-gpu.yml               optimizer_test.py    sanity_check.py
#  bert.py         evaluation.py            'output (1).txt'      setup.sh
#  classifier.py   further_pretrain.py       output.txt           task_sampler.py
#  config.py       gradient_surgery.py       predictions/         tokenizer.py
#  data/           LICENSE                   predictions.zip      Untitled0.ipynb
#  datasets.py     multitask_classifier.py   prepare_submit.py    utils.py
#  data_utils.py   multitask.pt              __pycache__/         wandb/
#  dfp_opt.zip     optimizer.py              README.md

# %%
# !python3 multitask_classifier.py --fine-tune-mode full-model --lr 1e-5 --epochs 10 --run_tests --use_wandb --joint --pal True --task_sampler annealed --use_gs --use_gpu --update_size 32 --batch_size 1 --n_steps 2500 | tee output.txt
# Out:
# Downloading: 100% 570/570 [00:00<00:00, 2.99MB/s]
# Downloading: 100% 440M/440M [00:04<00:00, 94.8MB/s]
# Downloading: 100% 232k/232k [00:00<00:00, 5.45MB/s]
# Loaded 8544 train examples from data/ids-sst-train.csv
# Loaded 1101 dev examples from data/ids-sst-dev.csv
# Loaded 282994 train examples from data/quora-train.csv
# Loaded 40428 dev examples from data/quora-dev.csv
# Loaded 6040 train examples from data/sts-train.csv
# Loaded 863 dev examples from data/sts-dev.csv
# # of parameters to be learned 114947131
# Not using wandb
# Running multi task
# Using Gradient Surgery
# train-0: 100% 2500/2500 [1:26:10<00:00,  2.07s/it]
# Batches per task:  {'qqq': 75000, 'sst': 2500, 'sts': 2500}
# eval: 100% 35/35 [00:01<00:00, 18.62it/s]
# eval: 100% 1264/1264 [02:31<00:00,  8.34it/s]
# eval: 100% 27/27 [00:03<00:00,  8.54it/s]
# Sentiment classification accuracy: 0.461
# Paraphrase detection accuracy: 0.808
# Semantic Textual Similarity correlation: 0.842
# ...

# %%
# !python3 multitask_classifier.py --fine-tune-mode full-model --lr 1e-5 --epochs 10 --run_tests --use_wandb --joint --pal True --task_sampler random --use_gs --use_gpu --update_size 32 --batch_size 1 --n_steps 2500 | tee output.txt
# Out:
# Downloading: 100% 570/570 [00:00<00:00, 3.46MB/s]
# Downloading: 100% 440M/440M [00:04<00:00, 89.0MB/s]
# Downloading: 100% 232k/232k [00:00<00:00, 47.7MB/s]
# Loaded 8544 train examples from data/ids-sst-train.csv
# Loaded 1101 dev examples from data/ids-sst-dev.csv
# Loaded 282994 train examples from data/quora-train.csv
# Loaded 40428 dev examples from data/quora-dev.csv
# Loaded 6040 train examples from data/sts-train.csv
# Loaded 863 dev examples from data/sts-dev.csv
# # of parameters to be learned 114947131
# Not using wandb
# Running multi task
# Using Gradient Surgery
# train-0: 100% 2500/2500 [1:25:58<00:00,  2.06s/it]
# Batches per task:  {'qqq': 26668, 'sst': 26630, 'sts': 26702}
# eval: 100% 35/35 [00:01<00:00, 18.68it/s]
# eval: 100% 1264/1264 [02:29<00:00,  8.45it/s]
# eval: 100% 27/27 [00:03<00:00,  8.71it/s]
# Sentiment classification accuracy: 0.505
# Paraphrase detection accuracy: 0.812
# Semantic Textual Similarity correlation: 0.865
# ...

# %%
# !pip install wandb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 21.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 28.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.6/289.6 kB 36.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.8 MB/s eta 0:00:00
# ...

# %%
import wandb
wandb.init()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-a00e484cd071> in <cell line: 2>()
#       1 import wandb
# ----> 2 wandb.init()
#       3 #2ffbe42fca299809414a6e11a3ca5b912958f4f4
#
# AttributeError: module 'wandb' has no attribute 'init'

# %%
import wandb

# %%
# !python3 multitask_classifier.py --fine-tune-mode full-model --lr 1e-5 --epochs 10 --run_tests --use_wandb --joint --task_sampler prop --use_gpu --batch_size 32 --n_steps 2500 | tee output.txt
# Out:
# Loaded 8544 train examples from data/ids-sst-train.csv
# Loaded 1101 dev examples from data/ids-sst-dev.csv
# Loaded 282994 train examples from data/quora-train.csv
# Loaded 40428 dev examples from data/quora-dev.csv
# Loaded 6040 train examples from data/sts-train.csv
# Loaded 863 dev examples from data/sts-dev.csv
# # of parameters to be learned 109487623
# Not using wandb
# Running multi task
# Total batches per epoch:  9300
# train-0: 100% 2500/2500 [08:23<00:00,  4.96it/s]
# Batches per task:  {'qqq': 802, 'sst': 852, 'sts': 846}
# eval: 100% 35/35 [00:01<00:00, 20.92it/s]
# eval: 100% 1264/1264 [02:21<00:00,  8.91it/s]
# eval: 100% 27/27 [00:02<00:00,  9.19it/s]
# Sentiment classification accuracy: 0.512
# Paraphrase detection accuracy: 0.806
# Semantic Textual Similarity correlation: 0.853
# save the model to multitask.pt
# Epoch 0: Avg dev :: 0.748, dev SST acc :: 0.512, dev QQQ acc :: 0.806, dev STS corr :: 0.853
# ...

# %%
# !python3 multitask_classifier.py --fine-tune-mode full-model --lr 1e-5 --epochs 10 --run_tests --use_wandb --joint --task_sampler random --use_gs --use_gpu --update_size 32 --batch_size 1 --n_steps 2500 | tee output.txt
# Out:
# Loaded 8544 train examples from data/ids-sst-train.csv
# Loaded 1101 dev examples from data/ids-sst-dev.csv
# Loaded 282994 train examples from data/quora-train.csv
# Loaded 40428 dev examples from data/quora-dev.csv
# Loaded 6040 train examples from data/sts-train.csv
# Loaded 863 dev examples from data/sts-dev.csv
# # of parameters to be learned 109487623
# Not using wandb
# Running multi task
# Using Gradient Surgery
# train-0: 100% 2500/2500 [53:49<00:00,  1.29s/it]
# Batches per task:  {'qqq': 26668, 'sst': 26630, 'sts': 26702}
# eval: 100% 35/35 [00:01<00:00, 21.12it/s]
# eval: 100% 1264/1264 [02:20<00:00,  8.98it/s]
# eval: 100% 27/27 [00:02<00:00,  9.26it/s]
# Sentiment classification accuracy: 0.501
# Paraphrase detection accuracy: 0.808
# Semantic Textual Similarity correlation: 0.859
# save the model to multitask.pt
# Epoch 0: Avg dev :: 0.746, dev SST acc :: 0.501, dev QQQ acc :: 0.808, dev STS corr :: 0.859
# ...
